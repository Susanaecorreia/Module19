# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
#import tensorflow.keras as keras
import numpy as np

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome.values
X = diabetes_df.drop(columns="Outcome").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Train on 576 samples
# Epoch 1/50
# 576/576 [==============================] - 0s 763us/sample - loss: 0.7210 - accuracy: 0.5208
# Epoch 2/50
# 576/576 [==============================] - 0s 34us/sample - loss: 0.6676 - accuracy: 0.6024
# Epoch 3/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.6267 - accuracy: 0.6701
# Epoch 4/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.5967 - accuracy: 0.7135
# Epoch 5/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.5714 - accuracy: 0.7500
# Epoch 6/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.5519 - accuracy: 0.7552
# Epoch 7/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5369 - accuracy: 0.7535
# Epoch 8/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.5241 - accuracy: 0.7535
# Epoch 9/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.5144 - accuracy: 0.7587
# Epoch 10/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.5061 - accuracy: 0.7674
# Epoch 11/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4993 - accuracy: 0.7726
# Epoch 12/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4933 - accuracy: 0.7743
# Epoch 13/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4884 - accuracy: 0.7778
# Epoch 14/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4844 - accuracy: 0.7743
# Epoch 15/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4805 - accuracy: 0.7760
# Epoch 16/50
# 576/576 [==============================] - 0s 34us/sample - loss: 0.4767 - accuracy: 0.7795
# Epoch 17/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4739 - accuracy: 0.7830
# Epoch 18/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4713 - accuracy: 0.7830
# Epoch 19/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4686 - accuracy: 0.7847
# Epoch 20/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4663 - accuracy: 0.7882
# Epoch 21/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4643 - accuracy: 0.7882
# Epoch 22/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4623 - accuracy: 0.7865
# Epoch 23/50
# 576/576 [==============================] - 0s 28us/sample - loss: 0.4603 - accuracy: 0.7882
# Epoch 24/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4593 - accuracy: 0.7882
# Epoch 25/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4574 - accuracy: 0.7882
# Epoch 26/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4562 - accuracy: 0.7882
# Epoch 27/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4547 - accuracy: 0.7899
# Epoch 28/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4535 - accuracy: 0.7899
# Epoch 29/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4526 - accuracy: 0.7899
# Epoch 30/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4515 - accuracy: 0.7899
# Epoch 31/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4505 - accuracy: 0.7899
# Epoch 32/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4498 - accuracy: 0.7917
# Epoch 33/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4487 - accuracy: 0.7934
# Epoch 34/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4479 - accuracy: 0.7934
# Epoch 35/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4469 - accuracy: 0.7934
# Epoch 36/50
# 576/576 [==============================] - 0s 34us/sample - loss: 0.4467 - accuracy: 0.7917
# Epoch 37/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4455 - accuracy: 0.7934
# Epoch 38/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4450 - accuracy: 0.7969
# Epoch 39/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4442 - accuracy: 0.7969
# Epoch 40/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4436 - accuracy: 0.7969
# Epoch 41/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4427 - accuracy: 0.7986
# Epoch 42/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4425 - accuracy: 0.7986
# Epoch 43/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4418 - accuracy: 0.7986
# Epoch 44/50
# 576/576 [==============================] - 0s 32us/sample - loss: 0.4409 - accuracy: 0.7986
# Epoch 45/50
# 576/576 [==============================] - 0s 34us/sample - loss: 0.4405 - accuracy: 0.7951
# Epoch 46/50
# 576/576 [==============================] - 0s 30us/sample - loss: 0.4399 - accuracy: 0.7951
# Epoch 47/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4392 - accuracy: 0.7951
# Epoch 48/50
# 576/576 [==============================] - 0s 31us/sample - loss: 0.4388 - accuracy: 0.7951
# Epoch 49/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4379 - accuracy: 0.7986
# Epoch 50/50
# 576/576 [==============================] - 0s 33us/sample - loss: 0.4372 - accuracy: 0.7969

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 192/1 - 0s - loss: 0.5364 - accuracy: 0.7135
# Loss: 0.5105805148681005, Accuracy: 0.7135416865348816
